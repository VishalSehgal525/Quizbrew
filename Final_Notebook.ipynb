# %%
import pandas as pd
import numpy as np

import torch
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint
from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5TokenizerFast as T5Tokenizer
)

# %%
pl.seed_everything(42)
# Out:
# Global seed set to 42
# 42

# %%
MODEL_NAME = 't5-small'
LEARNING_RATE = 0.0001

# %%
SEP_TOKEN = '<sep>'
tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)
print('tokenizer len before: ', len(tokenizer))
tokenizer.add_tokens(SEP_TOKEN)
print('tokenizer len after: ', len(tokenizer))
TOKENIZER_LEN = len(tokenizer)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# tokenizer len before:  32100
# tokenizer len after:  32101

# %%
class QGModel(pl.LightningModule):
    def __init__(self):
        super().__init__()
        self.model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME, return_dict=True)
        self.model.resize_token_embeddings(TOKENIZER_LEN) #resizing after adding new tokens to the tokenizer

    def forward(self, input_ids, attention_mask, labels=None):
        output = self.model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        return output.loss, output.logits

    def training_step(self, batch, batch_idx):
        input_ids = batch['input_ids']
        attention_mask = batch['attention_mask']
        labels = batch['labels']
        loss, output = self(input_ids, attention_mask, labels)
        self.log('train_loss', loss, prog_bar=True, logger=True)
        return loss

    def validation_step(self, batch, batch_idx):
        input_ids = batch['input_ids']
        attention_mask = batch['attention_mask']
        labels = batch['labels']
        loss, output = self(input_ids, attention_mask, labels)
        self.log('val_loss', loss, prog_bar=True, logger=True)
        return loss

    def test_step(self, batch, batch_idx):
        input_ids = batch['input_ids']
        attention_mask = batch['attention_mask']
        labels = batch['labels']
        loss, output = self(input_ids, attention_mask, labels)
        self.log('test_loss', loss, prog_bar=True, logger=True)
        return loss
  
    def configure_optimizers(self):
        return AdamW(self.parameters(), lr=LEARNING_RATE)

# %%
print(torch.__version__)
# Out:
# 2.0.1

# %%
checkpoint_path = "QA Generation Using T5 and SQuAD/best-checkpoint-v4.ckpt"
QGmodel = QGModel.load_from_checkpoint(checkpoint_path, map_location=torch.device('cpu'))
QGmodel.freeze()
QGmodel.eval()
# Out:
# QGModel(
#   (model): T5ForConditionalGeneration(
#     (shared): Embedding(32101, 512)
#     (encoder): T5Stack(
#       (embed_tokens): Embedding(32101, 512)
#       (block): ModuleList(
#         (0): T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#                 (relative_attention_bias): Embedding(32, 8)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1-5): 5 x T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (final_layer_norm): T5LayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (decoder): T5Stack(
#       (embed_tokens): Embedding(32101, 512)
#       (block): ModuleList(
#         (0): T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#                 (relative_attention_bias): Embedding(32, 8)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerCrossAttention(
#               (EncDecAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (2): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1-5): 5 x T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerCrossAttention(
#               (EncDecAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (2): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (final_layer_norm): T5LayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (lm_head): Linear(in_features=512, out_features=32101, bias=False)
#   )
# )

# %%
checkpoint_path = "Distractor Generation using T5 and RACE/best-checkpoint-v16.ckpt"
DstrModel = QGModel.load_from_checkpoint(checkpoint_path, map_location=torch.device('cpu'))
DstrModel.freeze()
DstrModel.eval()
# Out:
# QGModel(
#   (model): T5ForConditionalGeneration(
#     (shared): Embedding(32101, 512)
#     (encoder): T5Stack(
#       (embed_tokens): Embedding(32101, 512)
#       (block): ModuleList(
#         (0): T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#                 (relative_attention_bias): Embedding(32, 8)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1-5): 5 x T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (final_layer_norm): T5LayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (decoder): T5Stack(
#       (embed_tokens): Embedding(32101, 512)
#       (block): ModuleList(
#         (0): T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#                 (relative_attention_bias): Embedding(32, 8)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerCrossAttention(
#               (EncDecAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (2): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1-5): 5 x T5Block(
#           (layer): ModuleList(
#             (0): T5LayerSelfAttention(
#               (SelfAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): T5LayerCrossAttention(
#               (EncDecAttention): T5Attention(
#                 (q): Linear(in_features=512, out_features=512, bias=False)
#                 (k): Linear(in_features=512, out_features=512, bias=False)
#                 (v): Linear(in_features=512, out_features=512, bias=False)
#                 (o): Linear(in_features=512, out_features=512, bias=False)
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (2): T5LayerFF(
#               (DenseReluDense): T5DenseActDense(
#                 (wi): Linear(in_features=512, out_features=2048, bias=False)
#                 (wo): Linear(in_features=2048, out_features=512, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): ReLU()
#               )
#               (layer_norm): T5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (final_layer_norm): T5LayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (lm_head): Linear(in_features=512, out_features=32101, bias=False)
#   )
# )

# %%
def generateQuestion(qgmodel: QGModel, answer: str, context: str) -> str:
    source_encoding = tokenizer(
        '{} {} {}'.format(answer, SEP_TOKEN, context),
        max_length=300,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        add_special_tokens=True,
        return_tensors='pt'
    )

    generated_ids = qgmodel.model.generate(
        input_ids=source_encoding['input_ids'],
        attention_mask=source_encoding['attention_mask'],
        num_beams=1,
        max_length=80,
        repetition_penalty=2.5,
        length_penalty=1.0,
        early_stopping=True,
        use_cache=True
    )

    preds = {
        tokenizer.decode(generated_id, skip_special_tokens=False, clean_up_tokenization_spaces=True)
        for generated_id in generated_ids
    }

    return ''.join(preds)

# %%
def generateOptions(qgmodel: QGModel, answer: str, question: str, context: str) -> str:
    source_encoding = tokenizer(
        '{} {} {} {} {}'.format(answer, SEP_TOKEN, question, SEP_TOKEN, context),
        max_length=512,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        add_special_tokens=True,
        return_tensors='pt'
    )

    generated_ids = qgmodel.model.generate(
        input_ids=source_encoding['input_ids'],
        attention_mask=source_encoding['attention_mask'],
        num_beams=1,
        max_length=64,
        repetition_penalty=2.5,
        length_penalty=1.0,
        early_stopping=True,
        use_cache=True
    )

    preds = {
        tokenizer.decode(generated_id, skip_special_tokens=False, clean_up_tokenization_spaces=True)
        for generated_id in generated_ids
    }

    return ''.join(preds)

# %%
df_test = pd.read_csv("Datasets/RACE/race_test_df.csv")

# %%
df_test.head()
# Out:
#                                              context  \
# 0  The rain had continued for a week and the floo...
# 1  The rain had continued for a week and the floo...
# 2  The rain had continued for a week and the floo...
# 3  There is probably no field of human activity i...
# 4  There is probably no field of human activity i...
#
#                                             question  \
# 0     What did Nancy try to do before she fell over?
# 1  The following are true according to the passag...
# 2  What did the local people do to help those in ...
# 3                   The passage tells us that   _  .
# 4   Traditionally,people usually thought that   _  .
#
#                                              correct  \
# 0                Protect her cows from being drowned
# 1  Nancy took hold of the rope and climbed into t...
# 2          They put up shelter for them in a school.
# 3  the clothes that we choose to wear have someth...
# 4  women were concerned greatly about what they w...
#
#                                           incorrect1  \
# 0                     Measure the depth of the river
# 1  It took Lizzie and Nancy about 20 minutes to g...
# 2          They used helicopters to help carry cows.
# 3  our values and lifestyles are in no field of h...
# 4                    men cared very much for clothes
#
#                                           incorrect2  \
# 0                       Look for a fallen tree trunk
# 1  It was raining harder when Nancy managed to ge...
# 2             They helped farmers gather their cows.
# 3  our values and lifestyles are from the sign la...
# 4  both men and women paid great attention to the...
#
#                                           incorrect3
# 0                     Run away from the flooded farm
# 1  The bad weather made it difficult for rescuers...
# 2      They set up an organization called Red Cross.
# 3  the clothes we choose to wear depend on a set ...
# 4   neither men nor women showed interest in clothes

# %%
df_test['context'][0]
# Out:
# 'The rain had continued for a week and the flood had created a big river which were running by Nancy Brown\'s farm. As she tried to gather her cows to a higher ground, she slipped and hit her head on a fallen tree trunk. The fall made her unconscious for a moment or two. When she came to, Lizzie, one of her oldest and favorite cows, was licking her face. \nAt that time, the water level on the farm was still rising. Nancy gathered all her strength to get up and began walking slowly with Lizzie. The rain had become much heavier, and the water in the field was now waist high. Nancy\'s pace got slower and slower because she felt a great pain in her head. Finally, all she could do was to throw her arm around Lizzie\'s neck and try to hang on. About 20 minutes later, Lizzie managed to pull herself and Nancy out of the rising water and onto a bit of high land, which seemed like a small island in the middle of a lake of white water. \nEven though it was about noon, the sky was so dark and the rain and lightning was so bad that it took rescuers more than two hours to discover Nancy. A man from a helicopter  lowered a rope, but Nancy couldn\'t catch it. A moment later, two men landed on the small island from a ladder in the helicopter. They raised her into the helicopter and took her to the school gym, where the Red Cross had set up an emergency shelter. \nWhen the flood disappeared two days later, Nancy immediately went back to the "island." Lizzie was gone. She was one of 19 cows that Nancy had lost in the flood. "I owe my life to her," said Nancy with tears.'

# %%
generateQuestion(QGmodel, df_test['correct'][0], df_test['context'][0])
# Out:
# '<pad> Protect her cows from being drowned<sep> What was the main reason Lizzie fell on a tree trunk?</s>'

# %%
generateOptions(DstrModel, df_test['correct'][0], df_test['question'][0], df_test['context'][0])
# Out:
# '<pad> Get up and walk slowly with Lizzie<sep> Keep her feet licking herself in the field.<extra_id_29> Get up to get up quickly</s>'

# %%
def generate(answer, context):
    ques = generateQuestion(QGmodel, answer, context)
    # Extracting question
    flag = 0
    question = []
    for word in ques.split():
        if '</s>' in word:
            word = word.replace('</s>', '')
        if flag == 1:
            question.append(word)
        if '<sep>' in word:
            flag = 1
    question = ' '.join(question)
    optns = generateOptions(DstrModel, answer, question, context)
    # Extracting options
    flag = 0
    options = []
    temp = []
    optns = optns.replace('<', ' <')
    for word in optns.split():
        if word == '<pad>':
            continue
        if word == '<sep>':
            options.append(' '.join(temp))
            temp = []
            continue
        if '<extra_id' in word:
            options.append(' '.join(temp))
            temp = []
            continue
        if word == '</s>':
            options.append(' '.join(temp))
            temp = []
            continue
        temp.append(word)
    # options = {'correct': answer, 'incorrect': options}
    final_text = question + '\n'
    opt = {'a': answer}
    i = 1
    for o in options:
        opt[chr(97+i)] = o
        i = i+1
    final_text = 'Question: ' + question
    for keys in opt.keys():
        final_text = final_text + '\n' + keys + '. ' + opt[keys]
    final_text = final_text + '\n\nCorrect Options is a.'
    return final_text

# %%
df_test['correct'][2]
# Out:
# 'They put up shelter for them in a school.'

# %%
print(generate(df_test['correct'][2], df_test['context'][2]))
# Out:
# Question: What did the rescuers do to find Nancy?
# a. They put up shelter for them in a school.
# b. They lowered a rope.
# c. They lowered ice to catch her in the water and then put them into dangers on their farm, too!
# d. They landed on the island from frightened helicopter
#
# Correct Options is a.

# %%
import gradio as gr
interface = gr.Interface(
    fn=generate,
    inputs=["text", "text"],
    outputs="text",
    title="Generate Quiz",
    description="Generate mcqs for the given answer and context using T5 model.",
    examples=[
        [df_test['correct'][2], df_test['context'][2]],
    ]
)

interface.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Running on public URL: https://dfe319d6a959a9bce7.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://dfe319d6a959a9bce7.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Getting results

# %%
# !pip install evaluate
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 783.9 kB/s eta 0:00:00a 0:00:01
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp310-cp310-macosx_11_0_arm64.whl (31 kB)
# Requirement already satisfied: requests>=2.19.0 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from evaluate) (2.31.0)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from evaluate) (2023.5.0)
# Collecting dill
#   Using cached dill-0.3.6-py3-none-any.whl (110 kB)
# Requirement already satisfied: pandas in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from evaluate) (1.5.3)
# Requirement already satisfied: numpy>=1.17 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from evaluate) (1.23.5)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from evaluate) (0.14.1)
# Collecting responses<0.19
#   Using cached responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting datasets>=2.0.0
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from evaluate) (23.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from evaluate) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: aiohttp in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (3.8.4)
# Collecting pyarrow>=8.0.0
#   Downloading pyarrow-12.0.1-cp310-cp310-macosx_11_0_arm64.whl (22.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.6/22.6 MB 3.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.6.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: six>=1.5 in /Users/vishalsehgal/anaconda3/envs/torch/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: xxhash, pyarrow, dill, responses, multiprocess, datasets, evaluate
# Successfully installed datasets-2.12.0 dill-0.3.6 evaluate-0.4.0 multiprocess-0.70.14 pyarrow-12.0.1 responses-0.18.0 xxhash-3.2.0

# %%
results = []
for i in range(len(df_test)):
    results.append(generate(df_test['correct'][i], df_test['context'][i]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 3
#       1 results = []
#       2 for i in range(len(df_test)):
# ----> 3     results.append(generate(df_test['correct'][i], df_test['context'][i]))
#
# Cell In[35], line 2, in generate(answer, context)
#       1 def generate(answer, context):
# ----> 2     ques = generateQuestion(QGmodel, answer, context)
#       3     # Extracting question
#       4     flag = 0
#
# Cell In[28], line 12, in generateQuestion(qgmodel, answer, context)
#       1 def generateQuestion(qgmodel: QGModel, answer: str, context: str) -> str:
#       2     source_encoding = tokenizer(
#       3         '{} {} {}'.format(answer, SEP_TOKEN, context),
#       4         max_length=300,
#    (...)
#       9         return_tensors='pt'
#      10     )
# ---> 12     generated_ids = qgmodel.model.generate(
#      13         input_ids=source_encoding['input_ids'],
#      14         attention_mask=source_encoding['attention_mask'],
#      15         num_beams=1,
#      16         max_length=80,
#      17         repetition_penalty=2.5,
#      18         length_penalty=1.0,
#      19         early_stopping=True,
#      20         use_cache=True
#      21     )
#      23     preds = {
#      24         tokenizer.decode(generated_id, skip_special_tokens=False, clean_up_tokenization_spaces=True)
#      25         for generated_id in generated_ids
#      26     }
#      28     return ''.join(preds)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/generation/utils.py:1322, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, **kwargs)
#    1314         logger.warning(
#    1315             "A decoder-only architecture is being used, but right-padding was detected! For correct "
#    1316             "generation results, please set `padding_side='left'` when initializing the tokenizer."
#    1317         )
#    1319 if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    1320     # if model is encoder decoder encoder_outputs are created
#    1321     # and added to `model_kwargs`
# -> 1322     model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    1323         inputs_tensor, model_kwargs, model_input_name
#    1324     )
#    1326 # 5. Prepare `input_ids` which will be used for auto-regressive generation
#    1327 if self.config.is_encoder_decoder:
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/generation/utils.py:638, in GenerationMixin._prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name)
#     636 encoder_kwargs["return_dict"] = True
#     637 encoder_kwargs[model_input_name] = inputs_tensor
# --> 638 model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)
#     640 return model_kwargs
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:1086, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1073     layer_outputs = checkpoint(
#    1074         create_custom_forward(layer_module),
#    1075         hidden_states,
#    (...)
#    1083         None,  # past_key_value is always None with gradient checkpointing
#    1084     )
#    1085 else:
# -> 1086     layer_outputs = layer_module(
#    1087         hidden_states,
#    1088         attention_mask=extended_attention_mask,
#    1089         position_bias=position_bias,
#    1090         encoder_hidden_states=encoder_hidden_states,
#    1091         encoder_attention_mask=encoder_extended_attention_mask,
#    1092         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1093         layer_head_mask=layer_head_mask,
#    1094         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1095         past_key_value=past_key_value,
#    1096         use_cache=use_cache,
#    1097         output_attentions=output_attentions,
#    1098     )
#    1100 # layer_outputs is a tuple with:
#    1101 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1102 if use_cache is False:
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:693, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     690 else:
#     691     self_attn_past_key_value, cross_attn_past_key_value = None, None
# --> 693 self_attention_outputs = self.layer[0](
#     694     hidden_states,
#     695     attention_mask=attention_mask,
#     696     position_bias=position_bias,
#     697     layer_head_mask=layer_head_mask,
#     698     past_key_value=self_attn_past_key_value,
#     699     use_cache=use_cache,
#     700     output_attentions=output_attentions,
#     701 )
#     702 hidden_states, present_key_value_state = self_attention_outputs[:2]
#     703 attention_outputs = self_attention_outputs[2:]  # Keep self-attention outputs and relative position weights
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:600, in T5LayerSelfAttention.forward(self, hidden_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, output_attentions)
#     589 def forward(
#     590     self,
#     591     hidden_states,
#    (...)
#     597     output_attentions=False,
#     598 ):
#     599     normed_hidden_states = self.layer_norm(hidden_states)
# --> 600     attention_output = self.SelfAttention(
#     601         normed_hidden_states,
#     602         mask=attention_mask,
#     603         position_bias=position_bias,
#     604         layer_head_mask=layer_head_mask,
#     605         past_key_value=past_key_value,
#     606         use_cache=use_cache,
#     607         output_attentions=output_attentions,
#     608     )
#     609     hidden_states = hidden_states + self.dropout(attention_output[0])
#     610     outputs = (hidden_states,) + attention_output[1:]  # add attentions if we output them
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:525, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions)
#     521 # get key/value states
#     522 key_states = project(
#     523     hidden_states, self.k, key_value_states, past_key_value[0] if past_key_value is not None else None
#     524 )
# --> 525 value_states = project(
#     526     hidden_states, self.v, key_value_states, past_key_value[1] if past_key_value is not None else None
#     527 )
#     529 # compute scores
#     530 scores = torch.matmul(
#     531     query_states, key_states.transpose(3, 2)
#     532 )  # equivalent of torch.einsum("bnqd,bnkd->bnqk", query_states, key_states), compatible with onnx op>9
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:496, in T5Attention.forward.<locals>.project(hidden_states, proj_layer, key_value_states, past_key_value)
#     492 """projects hidden states correctly to key/query states"""
#     493 if key_value_states is None:
#     494     # self-attn
#     495     # (batch_size, n_heads, seq_length, dim_per_head)
# --> 496     hidden_states = shape(proj_layer(hidden_states))
#     497 elif past_key_value is None:
#     498     # cross-attn
#     499     # (batch_size, n_heads, seq_length, dim_per_head)
#     500     hidden_states = shape(proj_layer(key_value_states))
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
len(results)
# Out:
# 4608

# %%
print(results[4])
# Out:
# Question: What was the reason for the concern of clothes?
# a. women were concerned greatly about what they wore while men didn't
# b. Women were not aware of what they wore while men didn't
# c. Men were not aware about what they wore when women did.
# d. Women were too proud to wear clothes
#
# Correct Options is a.

# %%
file = open('items.txt','w')
for res in results:
    file.write(res+"\n")
file.close()
